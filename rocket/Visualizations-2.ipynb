# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from config import api_key
import gmaps
# Google developer API key
from config1 import gkey
# Access maps with unique API key
gmaps.configure(api_key=gkey)
import datetime
import numpy as np
rdf = pd.read_pickle('./launches.pickle')
rdf.head()
# Out:
#           rocket   family  rock_agency  \
# 0  Falcon 9 v1.1   Falcon       SpaceX
# 1    Antares 120  Antares  Orbital ATK
# 2   Ariane 5 ECA   Ariane           NA
# 3    Atlas V 401    Atlas           NA
# 4        Soyuz U    Soyuz           NA
#
#                                       location        lat        lon  result  \
# 0  Space Launch Complex 40, Cape Canaveral, FL  28.561941 -80.577357       1
# 1    Launch Area 0 A, Wallops Island, Virginia  37.833700 -75.488100       1
# 2                 Ariane Launch Area 3, Kourou   5.239000 -52.768000       1
# 3  Space Launch Complex 41, Cape Canaveral, FL  28.583410 -80.583036       1
# 4         1/5, Baikonur Cosmodrome, Kazakhstan  45.920000  63.342000       1
#
#   failreason                date                                  lsp_name  \
# 0         NA 2014-01-06 22:06:00                                    SpaceX
# 1         NA 2014-01-09 18:07:05              Orbital Sciences Corporation
# 2         NA 2014-02-06 21:30:07                               Arianespace
# 3         NA 2014-01-24 02:33:00                    United Launch Alliance
# 4         NA 2014-02-05 16:23:32  Russian Federal Space Agency (ROSCOSMOS)
#
#   lsp_country
# 0         USA
# 1         USA
# 2         FRA
# 3         USA
# 4         RUS

# %%
year = []
rdf['year'] = rdf['date'].dt.year
bins = [1969, 1980, 1990, 2000, 2010, 2020]
# Create the names for the four bins
group_names = ["1970's", "1980's", "1990's", "2000's", "2010's"]
rdf["Decade"] = pd.cut(rdf["year"], bins, labels=group_names)
rdf_f = rdf.loc[rdf['result'] == 0]
rdf_p = rdf.loc[rdf['result'] == 1]

# %%
k = pd.DataFrame(rdf_f.groupby(["lsp_country"]).lsp_country.count())
country_fails_name = k["lsp_country"].index.get_level_values(0).tolist()
k.reset_index(drop=True)
country_fails_count = k["lsp_country"].tolist()
fails_country = pd.DataFrame({'country_fails_name' : country_fails_name,
  'country_fails_count' : country_fails_count,
   }, columns=['country_fails_name','country_fails_count'])
fails_country.reset_index(drop=True)
s=[]
for i in range(len(rdf_f['lsp_country'])):
    for j in range(len(fails_country['country_fails_count'])):
        if list(rdf_f['lsp_country'])[i] == list(fails_country['country_fails_name'])[j]:
            s.append(list(fails_country['country_fails_count'])[j])
rdf_f["rating"] = s
rdf_f
# Out:
# C:\Users\safwa\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                rocket           family  \
# 36                      Falcon 9 v1.1           Falcon
# 76    Space Shuttle Challenger OV-099    Space Shuttle
# 82                    Proton-M/Briz-M  Proton / UR-500
# 83                         Soyuz 2.1a            Soyuz
# 105                  Soyuz 2-1v/Volga            Soyuz
# 119                             SPARK           Strypi
# 171                  Soyuz STB/Fregat            Soyuz
# 188                   Proton-M/Briz-M  Proton / UR-500
# 299     Space Shuttle Columbia OV-102    Space Shuttle
# 329    Falcon 9 Full Thrust (Block 3)           Falcon
# 479                     Falcon 9 v1.0           Falcon
# 495          Proton-M/Briz-M Enhanced  Proton / UR-500
# 547                           Soyuz U            Soyuz
# 614                        GSLV Mk II             GSLV
# 629                            Naro-1             Naro
# 669      Proton-M/Blok DM-03 Enhanced  Proton / UR-500
# 754                           Soyuz U            Soyuz
# 854                           Soyuz U            Soyuz
# 893                 Soyuz 2.1b/Fregat            Soyuz
# 903                          Electron         Electron
# 918                     Long March 4C     Long March 4
# 922                 Soyuz 2.1a/Fregat            Soyuz
# 925                      Pegasus HAPS          Pegasus
# 929                        Pegasus XL          Pegasus
# 932                        Pegasus XL          Pegasus
# 937                        Pegasus XL          Pegasus
# 952                        Pegasus XL          Pegasus
# 980                      Ariane 5 ECA           Ariane
# 1006                    Long March 2D     Long March 2
# 1011                         Zenit 3F            Zenit
# ...                               ...              ...
# 1286               Delta II 7920H-10C            Delta
# 1287                    Delta II 7320            Delta
# 1288                 Delta II 7420-10            Delta
# 1289                    Delta II 7420            Delta
# 1290                   Delta IV Heavy            Delta
# 1291                Delta II 7320-10C            Delta
# 1292                Delta II 7925-10L            Delta
# 1293                Delta II 7925-9.5            Delta
# 1294                Delta II 7920-10C            Delta
# 1295                 Delta IV M+(4,2)            Delta
# 1296                    Delta II 7925            Delta
# 1297                Delta II 7920-10C            Delta
# 1298                Delta II 7920-10C            Delta
# 1299                 Delta IV M+(5,4)            Delta
# 1300                Delta II 7320-10C            Delta
# 1301                      Atlas V 401            Atlas
# 1302                      Atlas V 401            Atlas
# 1303                      Atlas V 421            Atlas
# 1304                      Atlas V 401            Atlas
# 1305                      Atlas V 411            Atlas
# 1306                      Atlas V 421            Atlas
# 1307                      Atlas V 421            Atlas
# 1308                      Atlas V 401            Atlas
# 1309                      Atlas V 401            Atlas
# 1310                      Atlas V 401            Atlas
# 1311                      Atlas V 431            Atlas
# 1313                    Long March 3B     Long March 3
# 1314                   Delta IV Heavy            Delta
# 1315                         Simorgh           Simorgh
# 1372                         Zhuque-1           Zhuque
#
#                                             rock_agency  \
# 36                                               SpaceX
# 76        National Aeronautics and Space Administration
# 82                                                   NA
# 83                                                   NA
# 105                                                  NA
# 119                                                  NA
# 171                                                  NA
# 188                                                  NA
# 299       National Aeronautics and Space Administration
# 329                                              SpaceX
# 479                                              SpaceX
# 495                                                  NA
# 547                                                  NA
# 614                  Indian Space Research Organization
# 629   Khrunichev State Research and Production Space...
# 669                                                  NA
# 754                                                  NA
# 854                                                  NA
# 893                                                  NA
# 903                                      Rocket Lab Ltd
# 918   China Aerospace Science and Technology Corpora...
# 922                                                  NA
# 925                                         Orbital ATK
# 929                                         Orbital ATK
# 932                                         Orbital ATK
# 937                                         Orbital ATK
# 952                                         Orbital ATK
# 980                                                  NA
# 1006  China Aerospace Science and Technology Corpora...
# 1011                                                 NA
# ...                                                 ...
# 1286                                                 NA
# 1287                                                 NA
# 1288                                                 NA
# 1289                                                 NA
# 1290                                                 NA
# 1291                                                 NA
# 1292                                                 NA
# 1293                                                 NA
# 1294                                                 NA
# 1295                                                 NA
# 1296                                                 NA
# 1297                                                 NA
# 1298                                                 NA
# 1299                                                 NA
# 1300                                                 NA
# 1301                                                 NA
# 1302                                                 NA
# 1303                                                 NA
# 1304                                                 NA
# 1305                                                 NA
# 1306                                                 NA
# 1307                                                 NA
# 1308                                                 NA
# 1309                                                 NA
# 1310                                                 NA
# 1311                                                 NA
# 1313  China Aerospace Science and Technology Corpora...
# 1314                                                 NA
# 1315                                                 NA
# 1372                                          LandSpace
#
#                                                location        lat  \
# 36          Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 76         Launch Complex 39B, Kennedy Space Center, FL  28.627112
# 82       200/39 (200L), Baikonur Cosmodrome, Kazakhstan  46.039984
# 83                31/6, Baikonur Cosmodrome, Kazakhstan  45.996034
# 105             43/4 (43R), Plesetsk Cosmodrome, Russia  62.928830
# 119                                LP-41, Barking Sands  22.022778
# 171              Soyuz Launch Complex, Kourou/Sinnamary   5.301900
# 188        81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
# 299        Launch Complex 39A, Kennedy Space Center, FL  28.608227
# 329         Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 479         Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 495      200/39 (200L), Baikonur Cosmodrome, Kazakhstan  46.039984
# 547                1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 614        Satish Dhawan Space Centre Second Launch Pad  13.719900
# 629                                                Naro  34.431867
# 669        81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
# 754                1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 854                1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 893   Cosmodrome Site 1S, Vostochny Cosmodrome, Sibe...  51.884395
# 903                         Rocket Lab Launch Complex 1 -39.262833
# 918                           Launch Complex 9, Taiyuan  38.849000
# 922               31/6, Baikonur Cosmodrome, Kazakhstan  45.996034
# 925                              Edwards Air Force Base  34.905556
# 929                           Vandenberg Air Force Base  34.732778
# 932                           Vandenberg Air Force Base  34.732778
# 937                             Wallops Flight Facility  37.938611
# 952                           Vandenberg Air Force Base  34.732778
# 980                        Ariane Launch Area 3, Kourou   5.239000
# 1006                          Launch Complex 9, Taiyuan  38.849000
# 1011              45/1, Baikonur Cosmodrome, Kazakhstan  45.943492
# ...                                                 ...        ...
# 1286       Space Launch Complex 17B, Cape Canaveral, FL  28.445800
# 1287        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1288        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1289        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1290       Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 1291        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1292       Space Launch Complex 17B, Cape Canaveral, FL  28.445800
# 1293       Space Launch Complex 17A, Cape Canaveral, FL  28.447200
# 1294        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1295       Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 1296       Space Launch Complex 17A, Cape Canaveral, FL  28.447200
# 1297       Space Launch Complex 17B, Cape Canaveral, FL  28.445800
# 1298        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1299       Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 1300        Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 1301        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1302        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1303        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1304        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1305        Space Launch Complex 3E, Vandenberg AFB, CA  34.640000
# 1306        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1307        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1308        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1309        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1310        Space Launch Complex 3E, Vandenberg AFB, CA  34.640000
# 1311        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1313           Unknown, Xichang Satellite Launch Center  28.246017
# 1314       Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 1315                            Imam Khomeini Spaceport  35.238000
# 1372                               Unknown Pad, Jiuquan  40.958000
#
#              lon  result                                         failreason  \
# 36    -80.577357       0  Rapid Unscheduled Disassembly at T+ 2min19sec ...
# 76    -80.621015       0  During the ascent phase, 73 seconds after lift...
# 82     63.032093       0  Proton-M third stage vernier engine failed at ...
# 83     63.564003       0  After reaching low Earth orbit, but before sep...
# 105    40.457098       0
# 119  -159.785000       0  Vehicle lost attitude control around a minute ...
# 171   -52.834600       0  Satellites were placed into an incorrect orbit...
# 188    62.984999       0  The payload was placed into a lower than plann...
# 299   -80.604282       0  The seven members of the crew were killed on F...
# 329   -80.577357       0  Rocket and payload lost during anomaly origina...
# 479   -80.577357       0  Dragon was placed into the correct orbit after...
# 495    63.032093       0  The Breeze-M upper stage shutdown several minu...
# 547    63.342000       0  Approximately 325 seconds into flight, a malfu...
# 614    80.230400       0                               Third stage failure.
# 629   127.535069       0  Rapid Unscheduled Disassembly during first sta...
# 669    62.984999       0  Human error during fueling caused the upper st...
# 754    63.342000       0  Approximately 90 seconds before the intended l...
# 854    63.342000       0  The launch proceeded normally until telemetry ...
# 893   128.333932       0  An algorithm glitch caused the Fregat upper st...
# 903   177.864469       0  Third-party contractor supporting the launch m...
# 918   111.608000       0                                           Unknown.
# 922    63.564003       0  Numerous payloads experienced technical proble...
# 925  -117.883611       0
# 929  -120.568056       0  Flight termination after loss of vehicle contr...
# 932  -120.568056       0               Destroyed during second stage flight
# 937   -75.457222       0  Battery failure in the Pegasus XL rocket third...
# 952  -120.568056       0
# 980   -52.768000       0           Payloads placed into an incorrect orbit.
# 1006  111.608000       0   Satellites were placed into the incorrect orbit.
# 1011   63.653014       0
# ...          ...     ...                                                ...
# 1286  -80.565700       0
# 1287 -120.622400       0
# 1288 -120.622400       0
# 1289 -120.622400       0
# 1290  -80.564950       0
# 1291 -120.622400       0
# 1292  -80.565700       0
# 1293  -80.565000       0
# 1294 -120.622400       0
# 1295  -80.564950       0
# 1296  -80.565000       0
# 1297  -80.565700       0
# 1298 -120.622400       0
# 1299  -80.564950       0
# 1300 -120.622400       0
# 1301  -80.583036       0
# 1302  -80.583036       0
# 1303  -80.583036       0
# 1304  -80.583036       0
# 1305 -120.589500       0
# 1306  -80.583036       0
# 1307  -80.583036       0
# 1308  -80.583036       0
# 1309  -80.583036       0
# 1310 -120.589500       0
# 1311  -80.583036       0
# 1313  102.026556       0   The satellite was deployed into the wrong orbit.
# 1314  -80.564950       0  Two nanosats were lost after a first stage ano...
# 1315   53.950778       0  Failure due to a problem with the second stage...
# 1372  100.291000       0  Attitude control failed after third stage igni...
#
#                     date                                           lsp_name  \
# 36   2015-06-28 14:21:11                                             SpaceX
# 76   1986-01-28 16:38:00                  Lockheed Space Operations Company
# 82   2015-05-16 05:47:39                      International Launch Services
# 83   2015-04-28 07:09:50           Russian Federal Space Agency (ROSCOSMOS)
# 105  2015-12-05 14:09:00                               Russian Space Forces
# 119  2015-11-04 03:45:00                       Sandia National Laboratories
# 171  2014-08-22 12:27:11                                        Arianespace
# 188  2014-10-21 15:09:32  Khrunichev State Research and Production Space...
# 299  2003-01-16 15:39:00                              United Space Alliance
# 329  2016-09-03 09:00:00                                             SpaceX
# 479  2012-10-08 00:35:07                                             SpaceX
# 495  2012-12-08 13:13:43                      International Launch Services
# 547  2011-08-24 00:00:00           Russian Federal Space Agency (ROSCOSMOS)
# 614  2010-04-15 10:57:00                 Indian Space Research Organization
# 629  2010-06-10 08:01:00                 Korea Aerospace Research Institute
# 669  2010-12-05 10:25:00  Khrunichev State Research and Production Space...
# 754  1983-09-26 19:37:49                               Soviet Space Program
# 854  2016-12-01 14:51:52           Russian Federal Space Agency (ROSCOSMOS)
# 893  2017-11-28 05:41:46           Russian Federal Space Agency (ROSCOSMOS)
# 903  2017-05-25 05:00:00                                     Rocket Lab Ltd
# 918  2016-08-31 19:11:00  China Aerospace Science and Technology Corpora...
# 922  2017-07-14 06:36:49                                        Land Launch
# 925  1991-07-17 17:33:53                       Orbital Sciences Corporation
# 929  1994-06-27 21:15:00                       Orbital Sciences Corporation
# 932  1995-06-22 19:58:00                       Orbital Sciences Corporation
# 937  1996-11-04 17:08:00                       Orbital Sciences Corporation
# 952  2000-06-07 13:19:00                       Orbital Sciences Corporation
# 980  2018-01-25 23:05:00                                        Arianespace
# 1006 2016-12-28 03:23:00  China Aerospace Science and Technology Corpora...
# 1011 2017-12-26 19:00:03                                        Land Launch
# ...                  ...                                                ...
# 1286 2008-06-11 16:05:00                             United Launch Alliance
# 1287 2008-06-20 07:46:00                             United Launch Alliance
# 1288 2008-09-06 18:50:00                             United Launch Alliance
# 1289 2008-10-25 02:28:00                             United Launch Alliance
# 1290 2009-01-18 02:47:00                             United Launch Alliance
# 1291 2009-02-06 10:22:00                             United Launch Alliance
# 1292 2009-03-07 03:49:00                             United Launch Alliance
# 1293 2009-03-24 08:34:00                             United Launch Alliance
# 1294 2009-05-05 20:24:00                             United Launch Alliance
# 1295 2009-06-27 22:51:00                             United Launch Alliance
# 1296 2009-08-17 10:35:00                             United Launch Alliance
# 1297 2009-09-25 12:20:00                             United Launch Alliance
# 1298 2009-10-08 18:51:00                             United Launch Alliance
# 1299 2009-12-06 01:47:00                             United Launch Alliance
# 1300 2009-12-14 14:09:00                             United Launch Alliance
# 1301 2007-03-09 03:10:00                             United Launch Alliance
# 1302 2007-06-15 15:11:00                             United Launch Alliance
# 1303 2007-10-11 00:22:00                             United Launch Alliance
# 1304 2007-12-10 22:05:00                             United Launch Alliance
# 1305 2008-03-13 10:02:00                             United Launch Alliance
# 1306 2008-04-14 20:12:00                             United Launch Alliance
# 1307 2009-04-04 00:31:00                             United Launch Alliance
# 1308 2009-06-18 17:32:00                             United Launch Alliance
# 1309 2009-09-08 21:35:00                             United Launch Alliance
# 1310 2009-10-18 16:12:00                             United Launch Alliance
# 1311 2009-11-23 06:55:00                             United Launch Alliance
# 1313 2009-08-31 00:09:28  China Aerospace Science and Technology Corpora...
# 1314 2004-12-21 21:50:00                                             Boeing
# 1315 2017-07-27 09:30:00                               Iranian Space Agency
# 1372 2018-10-27 08:57:00                                          LandSpace
#
#      lsp_country  year  Decade  rating
# 36           USA  2015  2010's      55
# 76           USA  1986  1980's      55
# 82           USA  2015  2010's      55
# 83           RUS  2015  2010's      12
# 105          RUS  2015  2010's      12
# 119          USA  2015  2010's      55
# 171          FRA  2014  2010's       3
# 188          RUS  2014  2010's      12
# 299          USA  2003  2000's      55
# 329          USA  2016  2010's      55
# 479          USA  2012  2010's      55
# 495          USA  2012  2010's      55
# 547          RUS  2011  2010's      12
# 614          IND  2010  2000's       6
# 629          KOR  2010  2000's       1
# 669          RUS  2010  2000's      12
# 754          RUS  1983  1980's      12
# 854          RUS  2016  2010's      12
# 893          RUS  2017  2010's      12
# 903          NZL  2017  2010's       1
# 918          CHN  2016  2010's       5
# 922          RUS  2017  2010's      12
# 925          USA  1991  1990's      55
# 929          USA  1994  1990's      55
# 932          USA  1995  1990's      55
# 937          USA  1996  1990's      55
# 952          USA  2000  1990's      55
# 980          FRA  2018  2010's       3
# 1006         CHN  2016  2010's       5
# 1011         RUS  2017  2010's      12
# ...          ...   ...     ...     ...
# 1286         USA  2008  2000's      55
# 1287         USA  2008  2000's      55
# 1288         USA  2008  2000's      55
# 1289         USA  2008  2000's      55
# 1290         USA  2009  2000's      55
# 1291         USA  2009  2000's      55
# 1292         USA  2009  2000's      55
# 1293         USA  2009  2000's      55
# 1294         USA  2009  2000's      55
# 1295         USA  2009  2000's      55
# 1296         USA  2009  2000's      55
# 1297         USA  2009  2000's      55
# 1298         USA  2009  2000's      55
# 1299         USA  2009  2000's      55
# 1300         USA  2009  2000's      55
# 1301         USA  2007  2000's      55
# 1302         USA  2007  2000's      55
# 1303         USA  2007  2000's      55
# 1304         USA  2007  2000's      55
# 1305         USA  2008  2000's      55
# 1306         USA  2008  2000's      55
# 1307         USA  2009  2000's      55
# 1308         USA  2009  2000's      55
# 1309         USA  2009  2000's      55
# 1310         USA  2009  2000's      55
# 1311         USA  2009  2000's      55
# 1313         CHN  2009  2000's       5
# 1314         USA  2004  2000's      55
# 1315         IRN  2017  2010's       1
# 1372         CHN  2018  2010's       5
#
# [84 rows x 14 columns]

# %%
locations = rdf_f[["lat", "lon"]].astype(float)
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rdf_f["rating"], 
                                 dissipating=False, max_intensity=1,
                                 point_radius=5)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
l = pd.DataFrame(rdf_p.groupby(["lsp_country"]).lsp_country.count())
country_passes_name = l["lsp_country"].index.get_level_values(0).tolist()
country_passes_name
l.reset_index(drop=True)
country_passes_count = l["lsp_country"].tolist()
passes_country = pd.DataFrame({'country_passes_name' : country_passes_name,
  'country_passes_count' : country_passes_count,
   }, columns=['country_passes_name','country_passes_count'])
passes_country.reset_index(drop=True)
t=[]
for m in range(len(rdf_p['lsp_country'])):
     for n in range(len(passes_country['country_passes_count'])):
        if list(rdf_p['lsp_country'])[m] == list(passes_country['country_passes_name'])[n]:
             t.append(list(passes_country['country_passes_count'])[n])
rdf_p["rating"] = t
rdf_p
# Out:
# C:\Users\safwa\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      rocket           family  \
# 0             Falcon 9 v1.1           Falcon
# 1               Antares 120          Antares
# 2              Ariane 5 ECA           Ariane
# 3               Atlas V 401            Atlas
# 4                   Soyuz U            Soyuz
# 5           Proton-M/Briz-M  Proton / UR-500
# 6          Delta IV M+(4,2)            Delta
# 7                 H-IIA 202             H-II
# 8           Proton-M/Briz-M  Proton / UR-500
# 9              Ariane 5 ECA           Ariane
# 10        Soyuz 2.1b/Fregat            Soyuz
# 11              Atlas V 541            Atlas
# 12                  PSLV XL             PSLV
# 13              Atlas V 401            Atlas
# 14         Soyuz STA/Fregat            Soyuz
# 15                  Soyuz U            Soyuz
# 16                  Soyuz U            Soyuz
# 17          Proton-M/Briz-M  Proton / UR-500
# 18                     Vega             Vega
# 19          Proton-M/Briz-M  Proton / UR-500
# 20         Delta IV M+(4,2)            Delta
# 21              Atlas V 401            Atlas
# 22                H-IIA 202             H-II
# 23          Rokot / Briz-KM           UR-100
# 24                Zenit 3SL            Zenit
# 25            Falcon 9 v1.1           Falcon
# 26              Atlas V 551            Atlas
# 27        Delta II 7320-10C            Delta
# 28            Falcon 9 v1.1           Falcon
# 29              Atlas V 421            Atlas
# ...                     ...              ...
# 1358          Long March 2C     Long March 2
# 1359             KSLV 2 TLV             Naro
# 1360            Atlas V 551            Atlas
# 1361                 Vega-C             Vega
# 1362               Electron         Electron
# 1363       Falcon 9 Block 5           Falcon
# 1364       Falcon 9 Block 5           Falcon
# 1365               Soyuz-FG          Soyuz-U
# 1366               Soyuz-FG          Soyuz-U
# 1367               Soyuz-FG          Soyuz-U
# 1368             Soyuz 2.1a            Soyuz
# 1369             Soyuz 2.1a            Soyuz
# 1370                   Vega             Vega
# 1371  Long March 2C / YZ-1S     Long March 2
# 1373   Long March 3B / YZ-1     Long March 3
# 1374    Soyuz 2.1b/Fregat-M            Soyuz
# 1375             Soyuz 2.1b            Soyuz
# 1376           Falcon Heavy           Falcon
# 1377                   Vega             Vega
# 1378                   Vega             Vega
# 1379               Electron         Electron
# 1380          Long March 4B     Long March 4
# 1381          Long March 3B     Long March 3
# 1382                   Vega             Vega
# 1383           Falcon Heavy           Falcon
# 1384            Atlas V 551            Atlas
# 1385       Soyuz STA/Fregat            Soyuz
# 1386   Long March 3B / YZ-1     Long March 3
# 1387          Long March 2D     Long March 2
# 1388        Proton-M/Briz-M  Proton / UR-500
#
#                                             rock_agency  \
# 0                                                SpaceX
# 1                                           Orbital ATK
# 2                                                    NA
# 3                                                    NA
# 4                                                    NA
# 5                                                    NA
# 6                                                    NA
# 7                                                    NA
# 8                                                    NA
# 9                                                    NA
# 10                                                   NA
# 11                                                   NA
# 12                   Indian Space Research Organization
# 13                                                   NA
# 14                                                   NA
# 15                                                   NA
# 16                                                   NA
# 17                                                   NA
# 18                                                   NA
# 19                                                   NA
# 20                                                   NA
# 21                                                   NA
# 22                                                   NA
# 23    Khrunichev State Research and Production Space...
# 24                                                   NA
# 25                                               SpaceX
# 26                                                   NA
# 27                                                   NA
# 28                                               SpaceX
# 29                                                   NA
# ...                                                 ...
# 1358  China Aerospace Science and Technology Corpora...
# 1359  Khrunichev State Research and Production Space...
# 1360                                                 NA
# 1361                                                 NA
# 1362                                     Rocket Lab Ltd
# 1363                                             SpaceX
# 1364                                             SpaceX
# 1365                                                 NA
# 1366                                                 NA
# 1367                                                 NA
# 1368                                                 NA
# 1369                                                 NA
# 1370                                                 NA
# 1371  China Aerospace Science and Technology Corpora...
# 1373  China Aerospace Science and Technology Corpora...
# 1374                                                 NA
# 1375                                                 NA
# 1376                                             SpaceX
# 1377                                                 NA
# 1378                                                 NA
# 1379                                     Rocket Lab Ltd
# 1380  China Aerospace Science and Technology Corpora...
# 1381  China Aerospace Science and Technology Corpora...
# 1382                                                 NA
# 1383                                             SpaceX
# 1384                                                 NA
# 1385                                                 NA
# 1386  China Aerospace Science and Technology Corpora...
# 1387  China Aerospace Science and Technology Corpora...
# 1388                                                 NA
#
#                                                location        lat  \
# 0           Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 1             Launch Area 0 A, Wallops Island, Virginia  37.833700
# 2                          Ariane Launch Area 3, Kourou   5.239000
# 3           Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 4                  1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 5          81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
# 6          Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 7          Yoshinobu Launch Complex, Tanegashima, Japan  30.402222
# 8          81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
# 9                          Ariane Launch Area 3, Kourou   5.239000
# 10              43/4 (43R), Plesetsk Cosmodrome, Russia  62.928830
# 11          Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 12          Satish Dhawan Space Centre First Launch Pad  13.733000
# 13          Space Launch Complex 3E, Vandenberg AFB, CA  34.640000
# 14               Soyuz Launch Complex, Kourou/Sinnamary   5.301900
# 15                 1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 16                31/6, Baikonur Cosmodrome, Kazakhstan  45.996034
# 17         81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
# 18                         Ariane Launch Area 1, Kourou   5.236000
# 19       200/39 (200L), Baikonur Cosmodrome, Kazakhstan  46.039984
# 20         Space Launch Complex 37B, Cape Canaveral, FL  28.531700
# 21          Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 22         Yoshinobu Launch Complex, Tanegashima, Japan  30.402222
# 23            133/3 (133L), Plesetsk Cosmodrome, Russia  62.886999
# 24                     Launch Platform Odyssey, Pacific   0.000000
# 25          Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 26          Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 27          Space Launch Complex 2W, Vandenberg AFB, CA  34.755600
# 28          Space Launch Complex 40, Cape Canaveral, FL  28.561941
# 29          Space Launch Complex 41, Cape Canaveral, FL  28.583410
# ...                                                 ...        ...
# 1358                               Unknown Pad, Taiyuan  38.849000
# 1359                                               Naro  34.431867
# 1360        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1361                       Ariane Launch Area 1, Kourou   5.236000
# 1362                        Rocket Lab Launch Complex 1 -39.262833
# 1363                      Unknown Pad, Unknown Location   0.000000
# 1364                      Unknown Pad, Unknown Location   0.000000
# 1365               1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 1366               1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 1367               1/5, Baikonur Cosmodrome, Kazakhstan  45.920000
# 1368              31/6, Baikonur Cosmodrome, Kazakhstan  45.996034
# 1369              31/6, Baikonur Cosmodrome, Kazakhstan  45.996034
# 1370                       Ariane Launch Area 1, Kourou   5.236000
# 1371               Launch Area 4 (SLS-2 / 603), Jiuquan  40.960556
# 1373  Launch Complex 3 ( LC-3 ) ( LA-1 ), Xichang Sa...  28.246017
# 1374            43/4 (43R), Plesetsk Cosmodrome, Russia  62.928830
# 1375            43/4 (43R), Plesetsk Cosmodrome, Russia  62.928830
# 1376       Launch Complex 39A, Kennedy Space Center, FL  28.608227
# 1377                       Ariane Launch Area 1, Kourou   5.236000
# 1378                       Ariane Launch Area 1, Kourou   5.236000
# 1379  Rocket Lab Launch Complex 2, Wallops Island, V...  37.834000
# 1380                          Launch Complex 9, Taiyuan  38.849000
# 1381  Launch Complex 2 (LC-2), Xichang Satellite Lau...  28.246017
# 1382                       Ariane Launch Area 1, Kourou   5.236000
# 1383       Launch Complex 39A, Kennedy Space Center, FL  28.608227
# 1384        Space Launch Complex 41, Cape Canaveral, FL  28.583410
# 1385             Soyuz Launch Complex, Kourou/Sinnamary   5.301900
# 1386  Launch Complex 3 ( LC-3 ) ( LA-1 ), Xichang Sa...  28.246017
# 1387               Launch Area 4 (SLS-2 / 603), Jiuquan  40.960556
# 1388       81/24 (81P), Baikonur Cosmodrome, Kazakhstan  46.071001
#
#              lon  result failreason                date  \
# 0     -80.577357       1         NA 2014-01-06 22:06:00
# 1     -75.488100       1         NA 2014-01-09 18:07:05
# 2     -52.768000       1         NA 2014-02-06 21:30:07
# 3     -80.583036       1         NA 2014-01-24 02:33:00
# 4      63.342000       1         NA 2014-02-05 16:23:32
# 5      62.984999       1         NA 2014-02-14 21:09:03
# 6     -80.564950       1         NA 2014-02-21 01:59:00
# 7     130.975000       1         NA 2014-02-27 18:37:00
# 8      62.984999       1         NA 2014-03-15 23:08:00
# 9     -52.768000       1         NA 2014-03-22 22:04:07
# 10     40.457098       1         NA 2014-03-23 22:54:03
# 11    -80.583036       1         NA 2014-04-10 17:45:00
# 12     80.235000       1         NA 2014-04-04 11:44:00
# 13   -120.589500       1         NA 2014-04-03 14:46:30
# 14    -52.834600       1         NA 2014-04-04 21:02:26
# 15     63.342000       1         NA 2014-04-09 15:26:27
# 16     63.564003       1         NA 2014-04-16 16:20:00
# 17     62.984999       1         NA 2014-04-28 04:25:00
# 18    -52.775000       1         NA 2014-04-30 01:35:15
# 19     63.032093       1         NA 2014-05-15 21:42:00
# 20    -80.564950       1         NA 2014-05-17 00:03:00
# 21    -80.583036       1         NA 2014-05-22 13:09:00
# 22    130.975000       1         NA 2014-05-24 03:05:14
# 23     40.846984       1         NA 2014-05-23 05:27:54
# 24   -154.000000       1         NA 2014-05-26 21:09:59
# 25    -80.577357       1         NA 2015-01-10 09:47:10
# 26    -80.583036       1         NA 2015-01-21 01:04:00
# 27   -120.622400       1         NA 2015-01-31 14:22:00
# 28    -80.577357       1         NA 2015-02-11 23:03:32
# 29    -80.583036       1         NA 2015-03-13 02:44:00
# ...          ...     ...        ...                 ...
# 1358  111.608000       1         NA 2018-09-07 03:15:00
# 1359  127.535069       1         NA 1970-01-01 00:00:00
# 1360  -80.583036       1         NA 1970-01-01 00:00:00
# 1361  -52.775000       1         NA 1970-01-01 00:00:00
# 1362  177.864469       1         NA 1970-01-01 00:00:00
# 1363    0.000000       1         NA 1970-01-01 00:00:00
# 1364    0.000000       1         NA 1970-01-01 00:00:00
# 1365   63.342000       1         NA 1970-01-01 00:00:00
# 1366   63.342000       1         NA 1970-01-01 00:00:00
# 1367   63.342000       1         NA 1970-01-01 00:00:00
# 1368   63.564003       1         NA 1970-01-01 00:00:00
# 1369   63.564003       1         NA 1970-01-01 00:00:00
# 1370  -52.775000       1         NA 2018-11-21 01:42:31
# 1371  100.298333       1         NA 2018-10-09 03:03:00
# 1373  102.026556       1         NA 2018-10-15 04:42:00
# 1374   40.457098       1         NA 2018-11-03 23:30:00
# 1375   40.457098       1         NA 2018-10-25 03:00:00
# 1376  -80.604282       1         NA 1970-01-01 00:00:00
# 1377  -52.775000       1         NA 1970-01-01 00:00:00
# 1378  -52.775000       1         NA 1970-01-01 00:00:00
# 1379  -75.488000       1         NA 1970-01-01 00:00:00
# 1380  111.608000       1         NA 2018-10-24 22:57:00
# 1381  102.026556       1         NA 2018-11-01 17:13:00
# 1382  -52.775000       1         NA 1970-01-01 00:00:00
# 1383  -80.604282       1         NA 1970-01-01 00:00:00
# 1384  -80.583036       1         NA 2006-01-19 19:00:00
# 1385  -52.834600       1         NA 1970-01-01 00:00:00
# 1386  102.026556       1         NA 2018-11-18 18:26:00
# 1387  100.298333       1         NA 2018-11-20 23:56:00
# 1388   62.984999       1         NA 1970-01-01 00:00:00
#
#                                                lsp_name lsp_country  year  \
# 0                                                SpaceX         USA  2014
# 1                          Orbital Sciences Corporation         USA  2014
# 2                                           Arianespace         FRA  2014
# 3                                United Launch Alliance         USA  2014
# 4              Russian Federal Space Agency (ROSCOSMOS)         RUS  2014
# 5                         International Launch Services         USA  2014
# 6                                United Launch Alliance         USA  2014
# 7                           Mitsubishi Heavy Industries         JPN  2014
# 8     Khrunichev State Research and Production Space...         RUS  2014
# 9                                           Arianespace         FRA  2014
# 10                     Russian Aerospace Defence Forces         RUS  2014
# 11                               United Launch Alliance         USA  2014
# 12                   Indian Space Research Organization         IND  2014
# 13                               United Launch Alliance         USA  2014
# 14                                          Arianespace         FRA  2014
# 15             Russian Federal Space Agency (ROSCOSMOS)         RUS  2014
# 16             Russian Federal Space Agency (ROSCOSMOS)         RUS  2014
# 17    Khrunichev State Research and Production Space...         RUS  2014
# 18                                          Arianespace         FRA  2014
# 19    Khrunichev State Research and Production Space...         RUS  2014
# 20                               United Launch Alliance         USA  2014
# 21                               United Launch Alliance         USA  2014
# 22                          Mitsubishi Heavy Industries         JPN  2014
# 23                     Russian Aerospace Defence Forces         RUS  2014
# 24                                           Sea Launch         RUS  2014
# 25                                               SpaceX         USA  2015
# 26                               United Launch Alliance         USA  2015
# 27                               United Launch Alliance         USA  2015
# 28                                               SpaceX         USA  2015
# 29                               United Launch Alliance         USA  2015
# ...                                                 ...         ...   ...
# 1358  China Aerospace Science and Technology Corpora...         CHN  2018
# 1359                 Korea Aerospace Research Institute         KOR  1970
# 1360                             United Launch Alliance         USA  1970
# 1361                                        Arianespace         FRA  1970
# 1362                                     Rocket Lab Ltd         NZL  1970
# 1363                                             SpaceX         USA  1970
# 1364                                             SpaceX         USA  1970
# 1365           Russian Federal Space Agency (ROSCOSMOS)         RUS  1970
# 1366           Russian Federal Space Agency (ROSCOSMOS)         RUS  1970
# 1367           Russian Federal Space Agency (ROSCOSMOS)         RUS  1970
# 1368           Russian Federal Space Agency (ROSCOSMOS)         RUS  1970
# 1369           Russian Federal Space Agency (ROSCOSMOS)         RUS  1970
# 1370                                        Arianespace         FRA  2018
# 1371  China Aerospace Science and Technology Corpora...         CHN  2018
# 1373  China Aerospace Science and Technology Corpora...         CHN  2018
# 1374                               Russian Space Forces         RUS  2018
# 1375                               Russian Space Forces         RUS  2018
# 1376                                             SpaceX         USA  1970
# 1377                                        Arianespace         FRA  1970
# 1378                                        Arianespace         FRA  1970
# 1379                                     Rocket Lab Ltd         NZL  1970
# 1380  China Aerospace Science and Technology Corpora...         CHN  2018
# 1381  China Aerospace Science and Technology Corpora...         CHN  2018
# 1382                                        Arianespace         FRA  1970
# 1383                                             SpaceX         USA  1970
# 1384                             United Launch Alliance         USA  2006
# 1385                                        Arianespace         FRA  1970
# 1386  China Aerospace Science and Technology Corpora...         CHN  2018
# 1387  China Aerospace Science and Technology Corpora...         CHN  2018
# 1388  Khrunichev State Research and Production Space...         RUS  1970
#
#       Decade  rating
# 0     2010's     499
# 1     2010's     499
# 2     2010's     170
# 3     2010's     499
# 4     2010's     312
# 5     2010's     499
# 6     2010's     499
# 7     2010's      42
# 8     2010's     312
# 9     2010's     170
# 10    2010's     312
# 11    2010's     499
# 12    2010's      51
# 13    2010's     499
# 14    2010's     170
# 15    2010's     312
# 16    2010's     312
# 17    2010's     312
# 18    2010's     170
# 19    2010's     312
# 20    2010's     499
# 21    2010's     499
# 22    2010's      42
# 23    2010's     312
# 24    2010's     312
# 25    2010's     499
# 26    2010's     499
# 27    2010's     499
# 28    2010's     499
# 29    2010's     499
# ...      ...     ...
# 1358  2010's     196
# 1359  1970's       2
# 1360  1970's     499
# 1361  1970's     170
# 1362  1970's       7
# 1363  1970's     499
# 1364  1970's     499
# 1365  1970's     312
# 1366  1970's     312
# 1367  1970's     312
# 1368  1970's     312
# 1369  1970's     312
# 1370  2010's     170
# 1371  2010's     196
# 1373  2010's     196
# 1374  2010's     312
# 1375  2010's     312
# 1376  1970's     499
# 1377  1970's     170
# 1378  1970's     170
# 1379  1970's       7
# 1380  2010's     196
# 1381  2010's     196
# 1382  1970's     170
# 1383  1970's     499
# 1384  2000's     499
# 1385  1970's     170
# 1386  2010's     196
# 1387  2010's     196
# 1388  1970's     312
#
# [1305 rows x 14 columns]

# %%
locations1 = rdf_p[["lat", "lon"]].astype(float)
# Plot Heatmap
fig1 = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations1, weights=rdf_p["rating"], 
                                 dissipating=False, max_intensity=1,
                                 point_radius=2)

# Add layer
fig1.add_layer(heat_layer)

# Display figure
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
plt.figure(figsize=(20,20))
country_fails = rdf_f['lsp_country'].value_counts()
piefails = rdf_f.groupby(["lsp_country"]).count()["rocket"]
z= rdf_f.groupby(["lsp_country"]).count()["rocket"]
labels = z.index.get_level_values(0).tolist()
labels
plt.pie(rdf_f.groupby(["lsp_country"]).count()["rocket"], labels=labels,
        
        autopct="%1.1f%%", shadow=False, startangle=280)
mpl.rcParams['font.size'] = 2.0
plt.savefig('../Rocket Launch Failures per Country.png')

# %%
s = pd.DataFrame(rdf_f.groupby(["lsp_country","Decade"]).count())
# %matplotlib notebook
plt.figure(figsize=(8,4))
USA_F = [1,1,5,42,6]
RUS_F = [1,1,0,1,9]
NZL_F = [0,0,0,0,1]
KOR_F = [0,0,0,1,0]
IRN_F = [0,0,0,0,1]
IND_F = [0,0,0,5,1]
FRA_F = [0,0,1,0,2]
CHN_F = [0,0,0,1,4]
USA_F, = plt.plot(group_names,USA_F,label = "USA")
RUS_F, = plt.plot(group_names,RUS_F,label = "RUS")
NZL_F, = plt.plot(group_names,NZL_F,label = "NZL")
KOR_F, = plt.plot(group_names,KOR_F,label = "KOR")
IRN_F, = plt.plot(group_names,IRN_F,label = "IRN")
IND_F, = plt.plot(group_names,IND_F,label = "IND")
FRA_F, = plt.plot(group_names,FRA_F,label = "FRA")
CHN_F, = plt.plot(group_names,CHN_F,label = "CHN")
plt.legend()
plt.grid()
plt.title("Rocket Launch Failures per Country per Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Rocket Launches")
plt.ylim(-1,50)
plt.xlim(group_names[0],group_names[4])
plt.savefig('../Rocket Launch Failures per Country per Decade.png')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
t = pd.DataFrame(rdf_p.groupby(["lsp_country","Decade"]).count())
t.to_csv('out.csv')
# %matplotlib notebook
plt.figure(figsize=(8,8))
JPN_P = [6,0,0,3,33]
PRK_P = [0,0,0,0,3]
NA_P = [3,0,0,1,1]
FRA_RUS_P = [0,0,0,2,8]
USA_P = [108,38,88,65,200]
RUS_P = [72,24,20,41,155]
NZL_P = [5,0,0,0,2]
KOR_P = [1,0,0,0,1]
IRN_P = [2,0,0,0,3]
IND_P = [13,0,0,4,34]
FRA_P = [41,0,7,46,76]
CHN_P = [17,0,1,21,157]
ISR_P = [0,0,0,1,2]
USA_P, = plt.plot(group_names,USA_P,label = "USA")
RUS_P, = plt.plot(group_names,RUS_P,label = "RUS")
NZL_P, = plt.plot(group_names,NZL_P,label = "NZL")
KOR_P, = plt.plot(group_names,KOR_P,label = "KOR")
IRN_P, = plt.plot(group_names,IRN_P,label = "IRN")
IND_P, = plt.plot(group_names,IND_P,label = "IND")
FRA_P, = plt.plot(group_names,FRA_P,label = "FRA")
CHN_P, = plt.plot(group_names,CHN_P,label = "CHN")
ISR_P, = plt.plot(group_names,ISR_P,label = "ISR")
PKR_P, = plt.plot(group_names,PRK_P,label = "PKR")
JPN_P, = plt.plot(group_names,JPN_P,label = "JPN")
FRA_RUS_P, = plt.plot(group_names,FRA_RUS_P,label = "FRA_RUS")
NA_P, = plt.plot(group_names,NA_P,label = "NA") 
plt.legend()
plt.grid()
plt.title("Rocket Launch Successes per Country per Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Rocket Launches")
plt.ylim(-1,200)
plt.xlim(group_names[0],group_names[4])
plt.savefig('../Rocket Launch Successes per Country per Decade.png')
# Out:
# <img src="data:image/png;base64,..." width="799.259315720969">

# %%
u = pd.DataFrame(rdf.groupby(["lsp_country","Decade"]).count())
u.to_csv('saf.csv')
# %matplotlib notebook
plt.figure(figsize=(8,8))
JPN_T = [6,0,0,3,33]
PRK_T = [0,0,0,0,3]
NA_T = [3,0,0,1,1]
FRA_RUS_T = [0,0,0,2,8]
USA_T = [109,39,93,107,206]
RUS_T = [73,25,20,42,164]
NZL_T = [5,0,0,0,3]
KOR_T = [1,0,0,1,1]
IRN_T = [2,0,0,0,4]
IND_T = [13,0,0,9,35]
FRA_T = [41,0,8,46,78]
CHN_T = [17,0,1,22,161]
ISR_T = [0,0,0,1,2]
USA_T, = plt.plot(group_names,USA_T,label = "USA")
RUS_T, = plt.plot(group_names,RUS_T,label = "RUS")
NZL_T, = plt.plot(group_names,NZL_T,label = "NZL")
KOR_T, = plt.plot(group_names,KOR_T,label = "KOR")
IRN_T, = plt.plot(group_names,IRN_T,label = "IRN")
IND_T, = plt.plot(group_names,IND_T,label = "IND")
FRA_T, = plt.plot(group_names,FRA_T,label = "FRA")
CHN_T, = plt.plot(group_names,CHN_T,label = "CHN")
ISR_T, = plt.plot(group_names,ISR_T,label = "ISR")
PKR_T, = plt.plot(group_names,PRK_T,label = "PKR")
JPN_T, = plt.plot(group_names,JPN_T,label = "JPN")
FRA_RUS_T, = plt.plot(group_names,FRA_RUS_T,label = "FRA_RUS")
NA_T, = plt.plot(group_names,NA_T,label = "NA") 
plt.legend()
plt.grid()
plt.title("Total Rocket Launches per Country per Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Rocket Launches")
plt.ylim(-1,210)
plt.xlim(group_names[0],group_names[4])
plt.savefig('../Total Rocket Launches per Country per Decade.png')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
cat = pd.read_csv("safwan.csv")
category = pd.DataFrame(cat.groupby(['Failure_Category','Decade']).count())
category.head(100)
# %matplotlib notebook
plt.figure(figsize=(8,4))
Accidental_Failure = [0,0,2,3,5]
Human_Error = [0,0,1,4,7] 
System_Failure = [1,2,1,6,9]
Unknown_Failure = [1,0,2,37,3]
Accidental_Failure, = plt.plot(group_names,Accidental_Failure,label = "Accidental Failure")
Human_Error, = plt.plot(group_names,Human_Error,label = "Human Error")
System_Failure, = plt.plot(group_names,System_Failure,label = "System Failure")
Unknown_Failure, = plt.plot(group_names,Unknown_Failure,label = "Unknown Failure")
plt.legend()
plt.grid()
plt.title("Total Failures per Category per Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Failures")
plt.ylim(-1,38)
plt.xlim(group_names[0],group_names[4])
plt.savefig('../Total Failures per Category per Decade.png')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
country_category = pd.DataFrame(cat.groupby(['Failure_Category','lsp_country']).count())
country_category.head(400)
cat_type = ["Accidental Failure","Human Error","System Failure","Unknown Failure"]
# %matplotlib notebook
plt.figure(figsize=(8,4))
CHN = [1,2,1,1]
IND = [1,2,3,0] 
RUS = [2,3,4,3]
USA = [6,1,9,39]
FRA = [0,3,0,0]
NZL = [0,1,0,0]
IRN = [0,0,1,0]
KOR = [0,0,1,0]
CHN, = plt.plot(cat_type,CHN,label = "CHN")
IND, = plt.plot(cat_type,IND,label = "IND")
RUS, = plt.plot(cat_type,RUS,label = "RUS")
USA, = plt.plot(cat_type,USA,label = "USA")
FRA, = plt.plot(cat_type,FRA,label = "FRA")
NZL, = plt.plot(cat_type,NZL,label = "NZL")
IRN, = plt.plot(cat_type,IRN,label = "IRN")
KOR, = plt.plot(cat_type,KOR,label = "KOR")
plt.legend()
plt.grid()
plt.title("Total Failures per Country per Category")
plt.xlabel("Category Type")
plt.ylabel("Number of Failures")
plt.ylim(-1,40)
plt.xlim(cat_type[0],cat_type[3])
plt.savefig('../Total Failures per Country per Category.png')
# Out:
# <img src="data:image/png;base64,..." width="800">
